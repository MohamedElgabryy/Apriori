# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedElgabryy/Apriori/blob/main/Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from itertools import combinations

# Load the dataset from file
data = pd.read_excel('CoffeeShopTransactions.xlsx')

# Preprocess the data by converting strings to lowercase and removing spaces
columns = ['Transaction Number', 'Item 1', 'Item 2', 'Item 3']
data[columns] = data[columns].apply(lambda x: x.str.lower().str.replace(' ', '') if x.dtype == 'object' else x)

# Create a list of transactions and their items
transactions = []
for index, row in data.iterrows():
    transaction = row['Transaction Number'] 
    items = [row['Item 1'], row['Item 2'], row['Item 3']]
    items = [item for item in items if not pd.isnull(item)]
    transactions.append([transaction, items])

# Find the frequent itemsets
min_support_count = float(input("Enter the value of minimum support count : "))
frequent_itemsets = {}
for count in range(1, 1000):
    # Generate candidate itemsets of length count
    candidate_itemsets = set()
    for transaction in transactions:
        for itemset in combinations(transaction[1], count): 
            candidate_itemsets.add(frozenset(itemset)) 
            
    # Count the occurrences of each candidate itemset
    itemset_counts = {}
    for itemset in candidate_itemsets:
        itemset_counts[itemset] = 0 
        for transaction in transactions:
            if itemset.issubset(transaction[1]): 
                itemset_counts[itemset] += 1 
    
    # Find the frequent itemsets of length count
    frequent_itemsets[count] = {itemset: itemset_counts[itemset] for itemset in itemset_counts if itemset_counts[itemset] >= min_support_count}
    if len(frequent_itemsets[count]) == 0:
        break 

# Print the frequent itemsets
print("Frequent itemsets:")
for count in frequent_itemsets:
    for itemset in frequent_itemsets[count]:
        print(str(list(itemset)) + ": " + str(frequent_itemsets[count][itemset]))

# Find the association rules
min_confidence = float(input("Enter the minimum confidence: "))
association_rules = []
for count in range(2, len(frequent_itemsets)): 
    for itemset in frequent_itemsets[count]: 
        for i in range(1, count): 
            for antecedent in combinations(itemset, i): 
                consequent = itemset.difference(antecedent) 
                if len(consequent) == 0:  
                    continue
                support_antecedent = frequent_itemsets[i][frozenset(antecedent)] 
                support_consequent = frequent_itemsets[count-i][frozenset(consequent)]
                support_itemset = frequent_itemsets[count][itemset] 
                confidence = support_itemset / support_antecedent
                
                if confidence >= min_confidence: 
                    association_rules.append((antecedent, consequent, confidence)) 

# Print the association rules
print("Association rules:")
for rule in association_rules:
    print(str(list(rule[0])) + " -> " + str(list(rule[1])) + " | confidence = " + str(rule[2]))
# Out:
# Enter the value of minimum support count : 0.01
# Frequent itemsets:
# ['chocolates']: 1847
# ['juice']: 2197
# ['caramelbites']: 1893
# ['coffee']: 6327
# ['cake']: 2670
# ['mineralwater']: 2075
# ['cookies']: 2363
# ['hotchocolate']: 2416
# ['tea']: 3048
# ['brownie']: 2214
# ['chocolates']: 1847
# ['juice', 'cookies']: 362
# ['chocolates', 'brownie']: 262
# ['cake']: 2670
# ['hotchocolate', 'tea']: 543
# ['coffee', 'brownie']: 1201
# ['hotchocolate', 'mineralwater']: 325
# ['mineralwater', 'cake']: 384
# ['tea', 'brownie']: 497
# ['hotchocolate', 'caramelbites']: 293
# ['hotchocolate', 'chocolates']: 308
# ['coffee', 'hotchocolate']: 1285
# ['coffee', 'tea']: 1347
# ['juice', 'cake']: 433
# ['chocolates', 'tea']: 406
# ['hotchocolate', 'brownie']: 371
# ['caramelbites']: 1893
# ['brownie']: 2214
# ['chocolates', 'cookies']: 272
# ['juice', 'brownie']: 341
# ['juice', 'coffee']: 1219
# ['hotchocolate', 'cake']: 474
# ['juice', 'caramelbites']: 233
# ['juice', 'chocolates']: 256
# ['cookies', 'brownie']: 335
# ['juice', 'mineralwater']: 297
# ['juice', 'tea']: 522
# ['hotchocolate', 'cookies']: 373
# ['mineralwater']: 2075
# ['coffee', 'cookies']: 1260
# ['cake', 'cookies']: 485
# ['caramelbites', 'tea']: 471
# ['mineralwater', 'tea']: 518
# ['mineralwater', 'caramelbites']: 217
# ['coffee', 'chocolates']: 1102
# ['coffee', 'mineralwater']: 1209
# ['chocolates', 'caramelbites']: 191
# ['coffee', 'caramelbites']: 1126
# ['chocolates', 'mineralwater']: 235
# ['coffee', 'cake']: 1261
# ['mineralwater', 'brownie']: 303
# ['caramelbites', 'brownie']: 280
# ['mineralwater', 'cookies']: 347
# ['cookies']: 2363
# ['hotchocolate']: 2416
# ['juice']: 2197
# ['coffee']: 6327
# ['cake', 'brownie']: 450
# ['cookies', 'tea']: 527
# ['juice', 'hotchocolate']: 362
# ['cake', 'caramelbites']: 359
# ['chocolates', 'cake']: 375
# ['cookies', 'caramelbites']: 312
# ['cake', 'tea']: 598
# ['tea']: 3048
# ['juice', 'cookies']: 362
# ['hotchocolate', 'tea']: 543
# ['cake', 'mineralwater']: 384
# ['coffee', 'brownie']: 1201
# ['hotchocolate', 'mineralwater']: 325
# ['coffee', 'tea', 'hotchocolate']: 148
# ['juice', 'coffee', 'cookies']: 128
# ['hotchocolate', 'caramelbites']: 293
# ['mineralwater', 'caramelbites', 'brownie']: 14
# ['juice', 'chocolates', 'brownie']: 6
# ['chocolates', 'mineralwater', 'caramelbites']: 3
# ['chocolates', 'cookies', 'tea']: 32
# ['brownie', 'cookies', 'tea']: 34
# ['juice', 'caramelbites']: 233
# ['coffee', 'cookies', 'hotchocolate']: 123
# ['juice', 'coffee', 'tea']: 165
# ['juice', 'mineralwater']: 297
# ['chocolates', 'cake', 'brownie']: 33
# ['hotchocolate', 'cake', 'caramelbites']: 30
# ['hotchocolate', 'cake', 'mineralwater']: 31
# ['cake', 'cookies', 'brownie']: 44
# ['juice', 'brownie', 'tea']: 51
# ['juice', 'cake', 'cookies']: 42
# ['mineralwater', 'caramelbites']: 217
# ['coffee', 'caramelbites', 'tea']: 144
# ['hotchocolate', 'mineralwater', 'brownie']: 17
# ['chocolates', 'mineralwater', 'hotchocolate']: 15
# ['juice', 'hotchocolate', 'caramelbites']: 12
# ['cookies']: 2363
# ['chocolates', 'caramelbites', 'tea']: 23
# ['hotchocolate', 'cake', 'chocolates']: 33
# ['hotchocolate', 'cake', 'brownie']: 46
# ['cake', 'caramelbites']: 359
# ['coffee', 'cookies', 'chocolates']: 120
# ['coffee', 'cake', 'tea']: 141
# ['cake', 'tea']: 598
# ['juice', 'coffee', 'mineralwater']: 133
# ['hotchocolate', 'mineralwater', 'caramelbites']: 11
# ['coffee', 'tea', 'brownie']: 141
# ['cake']: 2670
# ['juice', 'cookies', 'tea']: 53
# ['juice', 'cookies', 'caramelbites']: 17
# ['brownie', 'tea']: 497
# ['juice', 'mineralwater', 'cookies']: 27
# ['hotchocolate', 'mineralwater', 'tea']: 46
# ['coffee', 'hotchocolate']: 1285
# ['coffee', 'caramelbites', 'brownie']: 120
# ['juice', 'hotchocolate', 'brownie']: 26
# ['chocolates', 'tea']: 406
# ['chocolates', 'tea', 'brownie']: 33
# ['juice', 'coffee', 'hotchocolate']: 146
# ['coffee', 'cookies', 'tea']: 129
# ['hotchocolate', 'cookies', 'brownie']: 30
# ['chocolates', 'cookies', 'hotchocolate']: 24
# ['coffee', 'cake', 'brownie']: 133
# ['hotchocolate', 'cake', 'tea']: 59
# ['chocolates', 'cookies', 'brownie']: 19
# ['juice', 'coffee', 'chocolates']: 127
# ['hotchocolate', 'caramelbites', 'chocolates']: 7
# ['coffee', 'cookies']: 1260
# ['caramelbites', 'tea']: 471
# ['mineralwater', 'tea']: 518
# ['coffee', 'chocolates']: 1102
# ['chocolates', 'mineralwater', 'tea']: 33
# ['mineralwater', 'cookies', 'cake']: 26
# ['hotchocolate', 'coffee', 'caramelbites']: 127
# ['brownie', 'mineralwater', 'tea']: 46
# ['juice']: 2197
# ['cake', 'cookies', 'tea']: 60
# ['juice', 'coffee', 'caramelbites']: 102
# ['mineralwater', 'cookies', 'brownie']: 21
# ['cookies', 'caramelbites', 'brownie']: 12
# ['chocolates', 'cookies', 'caramelbites']: 7
# ['cake', 'mineralwater', 'tea']: 59
# ['chocolates', 'mineralwater', 'cookies']: 16
# ['cake', 'caramelbites', 'tea']: 41
# ['coffee', 'mineralwater', 'brownie']: 130
# ['hotchocolate', 'caramelbites', 'tea']: 46
# ['mineralwater', 'caramelbites', 'cake']: 22
# ['juice', 'chocolates', 'caramelbites']: 9
# ['coffee', 'chocolates', 'hotchocolate']: 122
# ['hotchocolate', 'chocolates']: 308
# ['chocolates', 'mineralwater', 'brownie']: 12
# ['juice', 'cake']: 433
# ['coffee', 'tea']: 1347
# ['juice', 'chocolates', 'tea']: 30
# ['hotchocolate', 'brownie']: 371
# ['brownie', 'hotchocolate', 'tea']: 43
# ['chocolates', 'cake', 'mineralwater']: 28
# ['juice', 'brownie']: 341
# ['hotchocolate', 'chocolates', 'tea']: 39
# ['chocolates', 'cake', 'caramelbites']: 18
# ['cake', 'caramelbites', 'brownie']: 26
# ['hotchocolate', 'cake']: 474
# ['mineralwater', 'brownie', 'cake']: 33
# ['juice', 'chocolates']: 256
# ['hotchocolate', 'cookies', 'tea']: 53
# ['cake', 'cookies', 'caramelbites']: 38
# ['coffee', 'cookies', 'brownie']: 125
# ['juice', 'mineralwater', 'caramelbites']: 7
# ['coffee', 'mineralwater', 'hotchocolate']: 140
# ['brownie', 'caramelbites', 'tea']: 46
# ['juice', 'caramelbites', 'tea']: 35
# ['juice', 'hotchocolate', 'cake']: 36
# ['coffee', 'cake', 'cookies']: 159
# ['coffee', 'tea', 'chocolates']: 116
# ['juice', 'cake', 'brownie']: 48
# ['juice', 'chocolates', 'cake']: 24
# ['coffee', 'cake']: 1261
# ['mineralwater', 'brownie']: 303
# ['caramelbites', 'brownie']: 280
# ['chocolates', 'mineralwater']: 235
# ['hotchocolate']: 2416
# ['coffee', 'mineralwater', 'chocolates']: 115
# ['cake', 'brownie']: 450
# ['juice', 'chocolates', 'mineralwater']: 11
# ['chocolates', 'cake', 'cookies']: 28
# ['coffee', 'mineralwater', 'cookies']: 142
# ['cookies', 'tea']: 527
# ['juice', 'hotchocolate']: 362
# ['coffee', 'cookies', 'caramelbites']: 141
# ['chocolates', 'cake']: 375
# ['juice', 'mineralwater', 'brownie']: 17
# ['chocolates', 'caramelbites', 'brownie']: 8
# ['coffee', 'cake', 'chocolates']: 120
# ['cookies', 'caramelbites']: 312
# ['tea']: 3048
# ['chocolates', 'brownie']: 262
# ['juice', 'cake', 'mineralwater']: 29
# ['juice', 'hotchocolate', 'tea']: 49
# ['juice', 'cake', 'caramelbites']: 26
# ['juice', 'cake', 'tea']: 57
# ['brownie', 'coffee', 'chocolates']: 122
# ['juice', 'chocolates', 'cookies']: 16
# ['juice', 'cookies', 'brownie']: 27
# ['brownie']: 2214
# ['chocolates', 'cookies']: 272
# ['coffee', 'cake', 'caramelbites']: 126
# ['coffee', 'mineralwater', 'cake']: 125
# ['juice', 'coffee']: 1219
# ['juice', 'mineralwater', 'tea']: 33
# ['hotchocolate', 'mineralwater', 'cookies']: 29
# ['cookies', 'brownie']: 335
# ['hotchocolate', 'cookies', 'caramelbites']: 19
# ['hotchocolate', 'chocolates', 'brownie']: 20
# ['juice', 'tea']: 522
# ['hotchocolate', 'cookies']: 373
# ['juice', 'hotchocolate', 'chocolates']: 19
# ['coffee', 'caramelbites', 'chocolates']: 116
# ['cake', 'cookies']: 485
# ['juice', 'hotchocolate', 'cookies']: 24
# ['coffee', 'mineralwater']: 1209
# ['mineralwater', 'caramelbites', 'tea']: 39
# ['coffee', 'caramelbites']: 1126
# ['coffee', 'brownie', 'hotchocolate']: 127
# ['juice', 'caramelbites', 'brownie']: 15
# ['juice', 'coffee', 'cake']: 137
# ['mineralwater', 'cookies']: 347
# ['coffee']: 6327
# ['coffee', 'cake', 'hotchocolate']: 149
# ['coffee', 'mineralwater', 'tea']: 173
# ['tea', 'cake', 'brownie']: 49
# ['hotchocolate', 'caramelbites', 'brownie']: 25
# ['juice', 'coffee', 'brownie']: 131
# ['chocolates', 'cake', 'tea']: 56
# ['mineralwater', 'cookies', 'caramelbites']: 16
# ['cookies', 'caramelbites', 'tea']: 45
# ['hotchocolate', 'cake', 'cookies']: 42
# ['mineralwater', 'cookies', 'tea']: 48
# ['juice', 'hotchocolate', 'mineralwater']: 17
# ['coffee', 'mineralwater', 'caramelbites']: 96
# Enter the minimum confidence: 0.5
# Association rules:
# ['brownie'] -> ['coffee'] | confidence = 0.542457091237579
# ['hotchocolate'] -> ['coffee'] | confidence = 0.5318708609271523
# ['juice'] -> ['coffee'] | confidence = 0.5548475193445608
# ['cookies'] -> ['coffee'] | confidence = 0.5332204824375794
# ['chocolates'] -> ['coffee'] | confidence = 0.5966432051976177
# ['mineralwater'] -> ['coffee'] | confidence = 0.5826506024096385
# ['caramelbites'] -> ['coffee'] | confidence = 0.5948230322239831
# ['brownie'] -> ['coffee'] | confidence = 0.542457091237579
# ['hotchocolate'] -> ['coffee'] | confidence = 0.5318708609271523
# ['cookies'] -> ['coffee'] | confidence = 0.5332204824375794
# ['chocolates'] -> ['coffee'] | confidence = 0.5966432051976177
# ['juice'] -> ['coffee'] | confidence = 0.5548475193445608
# ['caramelbites', 'chocolates'] -> ['coffee'] | confidence = 0.6073298429319371
# ['mineralwater'] -> ['coffee'] | confidence = 0.5826506024096385
# ['caramelbites'] -> ['coffee'] | confidence = 0.5948230322239831
